# %% [markdown]
# # Laboratory Sesssion 3

# %% [markdown]
# ## Task 1

# %% [markdown]
# ## Task 2

# %% [markdown]
# ## Task 3: Comprehensive EDA Exercise
#
# This task combines skills from **Lab 1** (Python fundamentals), **Lab 2** (NumPy arrays), and **Lab 3** (Data Visualisation).
#
# ### Instructions
#
# Choose a dataset from [GitHub](https://github.com/datasets) or [Kaggle](https://www.kaggle.com/datasets) and complete the following:
#
# ---
#
# ### 3.1 Load Dataset
#
# - Import necessary libraries (pandas, numpy, matplotlib)
# - Load your chosen dataset into a DataFrame
# - Display the first few rows using `.head()`
#
# ### 3.2 Exploratory Data Analysis (EDA)
#
# - Check the shape of the dataset (rows and columns)
# - Display data types using `.dtypes` or `.info()`
# - Generate summary statistics using `.describe()`
# - Check for missing values using `.isnull().sum()`
#
# ### 3.3 Data Visualisation
#
# Create at least **three** visualisations:
#
# - **Line Chart** or **Bar Chart** for categorical/time-series data
# - **Histogram** for numerical distributions
# - **Box Plot** to identify outliers
#
# ### 3.4 Identify Data Issues
#
# Document any issues found in the dataset:
#
# - Missing values (which columns, how many?)
# - Outliers (identified from box plots)
# - Incorrect data types
# - Duplicate rows
#
# > **Note:** Do not perform data cleaning or pre-processing in this task. Simply identify and document the issues. Pre-processing will be covered in Lab 4.

# %%
# Task 3: Your code here
# 3.1 Load Dataset

# 3.2 EDA

# 3.3 Visualisation

# 3.4 Document Issues Found
